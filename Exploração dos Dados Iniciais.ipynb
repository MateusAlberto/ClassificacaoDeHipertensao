# %%
import pandas as pd

# %%
database = pd.read_csv('hipertensao.csv', sep=';')
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (506) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
database.shape
# Out:
# (25000, 942)

# %%
colunas = database.columns

# %%
colunas
# Out:
# Index(['V0001', 'V0024', 'UPA_PNS', 'V0006_PNS', 'UPA', 'V0025', 'C001',
#        'C00301', 'C004', 'C006',
#        ...
#        'V00281', 'V00291', 'V00282', 'V00292', 'V00283', 'V00293', 'VDD004',
#        'VDE001', 'VDE002', 'VDDATAM'],
#       dtype='object', length=942)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 942 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C001       25000 non-null  int64
#  7   C00301     25000 non-null  int64
#  8   C004       25000 non-null  int64
#  9   C006       25000 non-null  int64
#  10  C00701     25000 non-null  int64
#  11  C00702     25000 non-null  int64
#  12  C00703     25000 non-null  int64
#  13  C008       25000 non-null  int64
#  14  C009       25000 non-null  int64
#  15  C010       25000 non-null  float64
#  16  C011       25000 non-null  float64
#  17  C012       25000 non-null  int64
#  18  D001       25000 non-null  float64
# ...

# %%
database.dtypes
# Out:
# V0001          int64
# V0024          int64
# UPA_PNS        int64
# V0006_PNS      int64
# UPA            int64
#               ...
# V00293         int64
# VDD004       float64
# VDE001       float64
# VDE002       float64
# VDDATAM        int64
# Length: 942, dtype: object

# %%
print(pd.__version__)
# Out:
# 1.1.5

# %%
database.describe()
# Out:
#               V0001         V0024  ...        VDE002     VDDATAM
# count  25000.000000  2.500000e+04  ...  14145.000000     25000.0
# mean      30.631520  3.091012e+06  ...      1.045458  20161128.0
# std       11.869238  1.186529e+06  ...      0.208313         0.0
# min       11.000000  1.110011e+06  ...      1.000000  20161128.0
# 25%       23.000000  2.310211e+06  ...      1.000000  20161128.0
# 50%       31.000000  3.110113e+06  ...      1.000000  20161128.0
# 75%       41.000000  4.110211e+06  ...      1.000000  20161128.0
# max       53.000000  5.310220e+06  ...      2.000000  20161128.0
#
# [8 rows x 775 columns]

# %%
lista = ["L00201", "L00202", "L00203", "L003", "L004", "L005", "L006", "L007", "L008", "L009", "L010", "L011", "L012", "L013", "L014", "L015", "L01613", "L01614", "L01615", "L01616", "L01617", "L01618", "L01619", "L01620", "L01621", "L01622", "L01623", "L01624", "L01701", "L01702", "L01703", "L01704", "L01705", "L01706", "L01707", "L01708", "L01709", "L01710", "L01711", "L01712", "L01713", "L01714", "L01715", "L01716", "L018", "L019", "L020"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 895 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C001       25000 non-null  int64
#  7   C00301     25000 non-null  int64
#  8   C004       25000 non-null  int64
#  9   C006       25000 non-null  int64
#  10  C00701     25000 non-null  int64
#  11  C00702     25000 non-null  int64
#  12  C00703     25000 non-null  int64
#  13  C008       25000 non-null  int64
#  14  C009       25000 non-null  int64
#  15  C010       25000 non-null  float64
#  16  C011       25000 non-null  float64
#  17  C012       25000 non-null  int64
#  18  D001       25000 non-null  float64
# ...

# %%
lista = ["R001", "R002", "R003", "R004", "R005", "R006", "R007", "R008", "R009", "R010", "R011", "R012", "R013", "R014", "R015", "R016", "R017", "R018", "R019", "R020", "R021", "R022", "R023", "R024", "R025", "R026", "R027", "R028", "R029", "R030", "R031", "R032", "R033", "R034", "R035", "R03601", "R03602", "R03603", "R03604", "R03605", "R03606", "R03607", "R03608", "R03609", "R03610", "R03611", "R037", "R038", "R039", "R040", "R041", "R04101", "R042", "R04201", "R043", "R044", "R045", "R046", "R047", "R048", "R04901", "R04902", "R04903", "S001", "S002", "S003", "S004", "S005", "S006", "S007", "S008", "S009", "S01001", "S01002", "S01003", "S01004", "S01005", "S01101", "S01102", "S01103", "S012", "S013", "S01401", "S01402", "S01403", "S01404", "S01405", "S015", "S016", "S017", "S018", "S019", "S020", "S021", "S022", "S023", "S024", "S025", "S026", "S027", "S028", "S029", "S030", "S031", "S032", "S033", "S034", "S035", "S036", "S037", "S038", "S039", "S040", "S041", "S042", "S043", "S044", "S045", "S046", "S047", "S048", "S049", "S050", "S051", "S052", "S053", "S054", "S055", "S056", "S057", "S058", "U001", "U00201", "U00202", "U00203", "U004", "U005", "U006", "U009", "U010", "U011", "U014", "U015", "U01701", "U01702", "U01801", "U01802", "U019", "U020", "U021", "U022", "U023", "U02301", "U024", "U02401", "U025"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 739 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C001       25000 non-null  int64
#  7   C00301     25000 non-null  int64
#  8   C004       25000 non-null  int64
#  9   C006       25000 non-null  int64
#  10  C00701     25000 non-null  int64
#  11  C00702     25000 non-null  int64
#  12  C00703     25000 non-null  int64
#  13  C008       25000 non-null  int64
#  14  C009       25000 non-null  int64
#  15  C010       25000 non-null  float64
#  16  C011       25000 non-null  float64
#  17  C012       25000 non-null  int64
#  18  D001       25000 non-null  float64
# ...

# %%
database.C006
# Out:
# 0        2
# 1        2
# 2        2
# 3        1
# 4        2
#         ..
# 24995    1
# 24996    2
# 24997    1
# 24998    1
# 24999    2
# Name: C006, Length: 25000, dtype: int64

# %%
database.C006.unique()
# Out:
# array([2, 1])

# %%
database.C004.unique()
# Out:
# array([ 1,  2,  8, 13,  5,  9,  4, 12,  6,  3, 14,  7, 15, 16, 10, 17, 18])

# %%
lista = ["C001", "C00301", "C004", "C00701", "C00702", "C00703", "C011", "C012"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 731 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C006       25000 non-null  int64
#  7   C008       25000 non-null  int64
#  8   C009       25000 non-null  int64
#  9   C010       25000 non-null  float64
#  10  D001       25000 non-null  float64
#  11  D002       25000 non-null  float64
#  12  D003       1750 non-null   float64
#  13  D004       157 non-null    float64
#  14  D005       701 non-null    float64
#  15  D006       1430 non-null   float64
#  16  D007       906 non-null    float64
#  17  D008       23250 non-null  float64
#  18  D009       20926 non-null  float64
# ...

# %%
lista = ["D001", "D003", "D004", "D005", "D006", "D007", "D008", "D009", "D010", "D011", "D012", "D013", "D014", "D015"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 717 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C006       25000 non-null  int64
#  7   C008       25000 non-null  int64
#  8   C009       25000 non-null  int64
#  9   C010       25000 non-null  float64
#  10  D002       25000 non-null  float64
#  11  E001       25000 non-null  float64
#  12  E002       12465 non-null  float64
#  13  E003       12420 non-null  float64
#  14  E004       11939 non-null  float64
#  15  E005       11771 non-null  float64
#  16  E006       415 non-null    float64
#  17  E007       29 non-null     float64
#  18  E008       118 non-null    float64
# ...

# %%
database.E01802.unique()
# Out:
# array(['.', '00001600', '00000672', '00001356', '00001000', '00004000',
#        '00000300', '00001500', '00002500', '00001340', '00001200',
#        '00001800', '00000030', '00000160', '00000600', '00005000',
#        '00001300', '00000250', '00000678', '00000900', '00024000',
#        '00005400', '00000680', '00000100', '00000830', '00000800',
#        '00006000', '00000120', '00001700', '00000200', '00000278',
#        '00002600', '00000450', '00007000', '00000810', '00022000',
#        '00001360', '00000050', '00000150', '00000920', '00003000',
#        '00002100', '00000140', '00000620', '00000083', '00001301',
#        '00010000', '00002000', '00000400', '00000500', '00000070',
#        '00000720', '00002900', '00015000', '00000020', '00000700',
#        '00000080', '00003800', '00000015', '00003500', '00001850',
#        '00017000', '00000170', '00002200', '00002300', '00000340',
#        '00002550', '00001874', '00005500', '00001400', '00001250',
# ...

# %%
database.E01804.unique()
# Out:
# array(['.', '00000600', '00000300', '00000250', '00000180', '00000700',
#        '00000500'], dtype=object)

# %%
database.E019.unique()
# Out:
# array(['.', '040', '020', '048', '024', '030', '025', '005', '012', '015',
#        '036', '044', '060', '004', '028', '016', '050', '002', '010',
#        '027', '018', '003', '006', '014', '008', '021', '011', '032',
#        '007', '009', '022', '035', '100', '053', '058', '072', '001',
#        '043', '046', '042'], dtype=object)

# %%
lista = ["E004", "E005", "E006", "E007", "E008", "E01001", "E01002", "E01003", "E01201", "E01501", "E01601", "E01603", "E01605", "E01801", "E01803", "E01805", "E020", "E021", "E022", "E023", "E024", "E025", "E02501", "E02502", "E026", "E027"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 691 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C006       25000 non-null  int64
#  7   C008       25000 non-null  int64
#  8   C009       25000 non-null  int64
#  9   C010       25000 non-null  float64
#  10  D002       25000 non-null  float64
#  11  E001       25000 non-null  float64
#  12  E002       12465 non-null  float64
#  13  E003       12420 non-null  float64
#  14  E011       13502 non-null  float64
#  15  E014       13502 non-null  float64
#  16  E01602     25000 non-null  object
#  17  E01604     25000 non-null  object
#  18  E017       25000 non-null  object
# ...

# %%
lista = ["F001", "F00102", "F007", "F00702", "F008", "F00802"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["G001", "G002", "G00201", "G003", "G004", "G005", "G006", "G007", "G00701", "G008", "G009", "G010", "G014", "G015", "G01501", "G016", "G017", "G018", "G021", "G022", "G02201", "G023", "G024", "G02501", "G02502", "G02503", "G026", "G027", "G032"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.I003.unique()
# Out:
# array([nan,  2.,  1.])

# %%
lista = ["I002", "I003", "I004", "I005", "I006", "I007", "I00701", "I008", "I009", "I010", "I011"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["J002", "J003", "J004", "J005", "J006", "J007", "J008", "J009", "J010", "J013", "J014", "J015", "J016", "J017", "J018", "J019", "J020", "J021", "J022", "J023", "J024", "J025", "J026", "J027", "J029", "J030", "J031", "J032", "J033", "J034", "J035", "J036", "J037", "J038", "J039", "J04001", "J04002", "J041", "J042", "J043", "J044", "J045", "J046", "J047", "J048", "J049", "J050", "J051", "J052", "J053", "J054", "J055", "J056", "J057", "J058", "J059", "J060"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 588 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C006       25000 non-null  int64
#  7   C008       25000 non-null  int64
#  8   C009       25000 non-null  int64
#  9   C010       25000 non-null  float64
#  10  D002       25000 non-null  float64
#  11  E001       25000 non-null  float64
#  12  E002       12465 non-null  float64
#  13  E003       12420 non-null  float64
#  14  E011       13502 non-null  float64
#  15  E014       13502 non-null  float64
#  16  E01602     25000 non-null  object
#  17  E01604     25000 non-null  object
#  18  E017       25000 non-null  object
# ...

# %%
lista = ["K001", "K002", "K003", "K004", "K005", "K006", "K007", "K008", "K009", "K010", "K011", "K012", "K013", "K014", "K015", "K016", "K017", "K018", "K019", "K020", "K021", "K022", "K023", "K024", "K025", "K026", "K027", "K028", "K029", "K030", "K031", "K032", "K033", "K034", "K035", "K036", "K039", "K040", "K041", "K042", "K043", "K044", "K045", "K046", "K047", "K048", "K049", "K050", "K051", "K052", "K053", "K054", "K055", "K056", "K057", "K058", "K059", "K06001", "K06002", "K06003", "K06101", "K06102", "K062"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["M001", "M002", "M003", "M005", "M01301", "M01302", "M01303", "M017", "M018", "M019"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["N007", "N008", "N019", "N020", "N021", "N022", "N023"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["O004", "O005", "O006", "O007", "O008", "O009", "O00901", "O010", "O011", "O012", "O013", "O014", "O015", "O016", "O017", "O01801", "O01802", "O019", "O020", "O021", "O02101", "O022", "O023", "O024", "O025", "O027", "O028", "O029", "O030", "O031", "O032", "O033", "O034", "O035", "O036", "O037", "O038", "O039", "O040", "O041", "O042", "O043", "O044", "O045", "O046", "O047", "O048"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["P004", "P00401", "P021", "P030", "P036", "P046", "P047", "P048", "P049", "P052", "P057", "P060", "P061", "P062", "P063", "P064", "P065", "P066", "P069", "P07001", "P07002", "P07003", "P071", "P072"]

# %%
database.drop(columns=lista, inplace=True)

# %%
lista = ["Q003", "Q004", "Q005", "Q006", "Q007", "Q008", "Q009", "Q010", "Q011", "Q012", "Q013", "Q014", "Q015", "Q016", "Q017", "Q01801", "Q01802", "Q01803", "Q01804", "Q01805", "Q01806", "Q01807", "Q01808", "Q01901", "Q01902", "Q01903", "Q01904", "Q01905", "Q020", "Q021", "Q022", "Q023", "Q024", "Q026", "Q027", "Q028", "Q029", "Q030", "Q031", "Q032", "Q033", "Q03401", "Q03402", "Q035", "Q036", "Q037", "Q038", "Q039", "Q040", "Q041", "Q042", "Q043", "Q044", "Q045", "Q04601", "Q04602", "Q04603", "Q04604", "Q04605", "Q04606", "Q04607", "Q04608", "Q04609", "Q04701", "Q04702", "Q04703", "Q04704", "Q04705", "Q048", "Q049", "Q050", "Q051", "Q052", "Q053", "Q054", "Q05501", "Q05502", "Q05503", "Q05504", "Q05505", "Q05506", "Q05507", "Q05508", "Q05509", "Q056", "Q057", "Q058", "Q059", "Q060", "Q061", "Q06201", "Q06202", "Q06203", "Q06204", "Q06205", "Q06206", "Q063", "Q06301", "Q06302", "Q06303", "Q06304", "Q064", "Q06501", "Q06502", "Q06503", "Q06504", "Q066", "Q067", "Q068", "Q069", "Q070", "Q071", "Q07201", "Q07202", "Q07203", "Q07204", "Q07205", "Q07206", "Q073", "Q074", "Q075", "Q076", "Q07701", "Q07702", "Q078", "Q079", "Q080", "Q08101", "Q08102", "Q08103", "Q08104", "Q08105", "Q082", "Q083", "Q084", "Q085", "Q08601", "Q08603", "Q08604", "Q08605", "Q087", "Q088", "Q089", "Q09001", "Q09003", "Q09004", "Q09005", "Q091", "Q092", "Q093", "Q094", "Q095", "Q09601", "Q09602", "Q09603", "Q097", "Q098", "Q100", "Q101", "Q102", "Q103", "Q104", "Q105", "Q106", "Q107", "Q108", "Q109", "Q110", "Q11001", "Q11002", "Q11003", "Q11004", "Q111", "Q112", "Q113", "Q11401", "Q11402", "Q11403", "Q115", "Q116", "Q11601", "Q11602", "Q11603", "Q117", "Q11801", "Q11802", "Q11803", "Q11804", "Q119", "Q120", "Q121", "Q122", "Q123", "Q124", "Q125", "Q12601", "Q12602", "Q12603", "Q12604", "Q12605", "Q127", "Q128", "Q130", "Q131", "Q132", "Q133", "Q134", "Q135", "Q136", "Q137"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 227 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C006       25000 non-null  int64
#  7   C008       25000 non-null  int64
#  8   C009       25000 non-null  int64
#  9   C010       25000 non-null  float64
#  10  D002       25000 non-null  float64
#  11  E001       25000 non-null  float64
#  12  E002       12465 non-null  float64
#  13  E003       12420 non-null  float64
#  14  E011       13502 non-null  float64
#  15  E014       13502 non-null  float64
#  16  E01602     25000 non-null  object
#  17  E01604     25000 non-null  object
#  18  E017       25000 non-null  object
# ...

# %%
lista = ["X003", "X004", "X005", "X006", "X007", "X008", "X011", "X012", "X01401", "X01402", "X01501", "X01502", "X016", "X017", "X018", "X019", "X02001", "X02002", "X02003", "X02004", "X02005", "X02006", "X02201", "X02202", "X02203", "X02204", "X02205", "X02206", "X024", "X02501", "X02502", "X02503", "X02504", "X02505", "X02506", "X02507", "X02508", "X02509", "X02510"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 188 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   V0001      25000 non-null  int64
#  1   V0024      25000 non-null  int64
#  2   UPA_PNS    25000 non-null  int64
#  3   V0006_PNS  25000 non-null  int64
#  4   UPA        25000 non-null  int64
#  5   V0025      25000 non-null  int64
#  6   C006       25000 non-null  int64
#  7   C008       25000 non-null  int64
#  8   C009       25000 non-null  int64
#  9   C010       25000 non-null  float64
#  10  D002       25000 non-null  float64
#  11  E001       25000 non-null  float64
#  12  E002       12465 non-null  float64
#  13  E003       12420 non-null  float64
#  14  E011       13502 non-null  float64
#  15  E014       13502 non-null  float64
#  16  E01602     25000 non-null  object
#  17  E01604     25000 non-null  object
#  18  E017       25000 non-null  object
# ...

# %%
lista = ["V0001", "V0024", "UPA_PNS", "V0006_PNS", "UPA", "V0025", "W00101", "W00102", "W00103", "W00201", "W00202", "W00203", "W00301", "W00302", "W00303", "W00401", "W00402", "W00403", "W00404", "W00405", "W00406", "W00407", "W00408", "V0028", "V0029", "V00281", "V00291", "V00282", "V00292", "V00283", "V00293", "VDD004", "VDE001", "VDE002", "VDDATAM"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 153 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   C006      25000 non-null  int64
#  1   C008      25000 non-null  int64
#  2   C009      25000 non-null  int64
#  3   C010      25000 non-null  float64
#  4   D002      25000 non-null  float64
#  5   E001      25000 non-null  float64
#  6   E002      12465 non-null  float64
#  7   E003      12420 non-null  float64
#  8   E011      13502 non-null  float64
#  9   E014      13502 non-null  float64
#  10  E01602    25000 non-null  object
#  11  E01604    25000 non-null  object
#  12  E017      25000 non-null  object
#  13  E01802    25000 non-null  object
#  14  E01804    25000 non-null  object
#  15  E019      25000 non-null  object
#  16  VDF001    25000 non-null  int64
#  17  VDF00102  25000 non-null  object
#  18  I001      25000 non-null  int64
#  19  J001      25000 non-null  int64
# ...

# %%
database.M008.unique()
# Out:
# array([nan,  1.,  4.,  2.,  5.,  3.,  6.])

# %%
lista = ["VDF001", "VDF00102"]

# %%
database.drop(columns=lista, inplace=True)

# %%
database.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 151 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C006    25000 non-null  int64
#  1   C008    25000 non-null  int64
#  2   C009    25000 non-null  int64
#  3   C010    25000 non-null  float64
#  4   D002    25000 non-null  float64
#  5   E001    25000 non-null  float64
#  6   E002    12465 non-null  float64
#  7   E003    12420 non-null  float64
#  8   E011    13502 non-null  float64
#  9   E014    13502 non-null  float64
#  10  E01602  25000 non-null  object
#  11  E01604  25000 non-null  object
#  12  E017    25000 non-null  object
#  13  E01802  25000 non-null  object
#  14  E01804  25000 non-null  object
#  15  E019    25000 non-null  object
#  16  I001    25000 non-null  int64
#  17  J001    25000 non-null  int64
#  18  J011    25000 non-null  int64
#  19  J012    25000 non-null  object
#  20  M006    2047 non-null   float64
# ...
